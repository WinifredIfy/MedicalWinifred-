# %% [markdown]
# <a href="https://colab.research.google.com/github/WinifredIfy/MedicalWinifred-/blob/main/Section_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SO1

# %%
import numpy
from scipy import stats
Age= [36,24,25,33,24,29,27,31,24,23,30,39,26]
x=numpy.mean(Age)
print(x)
# Out:
# 28.53846153846154

# %%
x=numpy.median(Age)
print(x)
# Out:
# 27.0

# %%
x=numpy.var(Age)
print(x)
# Out:
# 23.633136094674555

# %%
x=stats.mode(Age)
print(x)
# Out:
# ModeResult(mode=24, count=3)

# %%
x=numpy.percentile(Age,25)
print(x)
# Out:
# 24.0

# %%
x=numpy.percentile(Age,75)
print(x)
# Out:
# 31.0

# %%
x=numpy.percentile(Age,50)
print(x)
# Out:
# 27.0

# %%
import pandas as pd

# %%
url= 'https://raw.githubusercontent.com/WinifredIfy/MedicalWinifred-/main/Medical_data.csv'
df = pd.read_csv (url)
df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
Medical =pd.read_csv(url)

# %%
Medical.head(442)
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
# [442 rows x 11 columns]

# %%
Medical.dtypes
# Out:
# AGE      int64
# SEX      int64
# BMI    float64
# BP     float64
# S1       int64
# S2     float64
# S3     float64
# S4     float64
# S5     float64
# S6       int64
# Y        int64
# dtype: object
